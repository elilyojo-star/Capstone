# %% [markdown]
# <a href="https://colab.research.google.com/github/elilyojo-star/Capstone/blob/main/Readme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Predicting Project Delivery Risk (Google Colab)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/)
#
# ## Assignment Rubric Alignment
# - ✅ Data Processing & Cleaning
# - ✅ Exploratory Data Analysis (EDA)
# - ✅ Feature Engineering
# - ✅ Regression Modeling
# - ✅ Model Evaluation & Comparison
# - ✅ Clear Documentation
#
# ## Repository Structure
# ```
# project_delivery_risk/
# ├── 01_CC1.ipynb
# ├── data/
# │   └── creditcard.csv
# ├── outputs/
# └── README
# ```
#
# ## How to Run (Google Colab)
# 1. Upload notebooks to Colab
# 2. Mount Google Drive when prompted
# 3. Place dataset in `MyDrive/project_delivery_risk/data/`
# 4. Run notebooks top-to-bottom
#
# ## Models Used
# - Linear Regression (baseline)
# - Random Forest Regression
#
# ## Notes
# - Random seed fixed for reproducibility
# - Metrics: RMSE, R²
